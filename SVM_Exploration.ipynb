# %% [markdown]
# # SVM Exploration

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn import svm, datasets

# %%
# import some data to play with
iris = datasets.load_iris()

X = iris.data[:, :2] # we only take the first two features
y = iris.target

# %%
# we create an instance of SVM and fit out data. We do not scale our
# data since we want to plot the support vectors

Cr = 1.0 # SVM regularization parameter
svc = svm.SVC(kernel='linear', C=Cr, gamma=0).fit(X, y)
# Out:
# /Users/jmalbornoz/anaconda/lib/python2.7/site-packages/sklearn/svm/base.py:85: DeprecationWarning: gamma=0.0 has been deprecated in favor of gamma='auto' as of 0.17. Backward compatibility for gamma=0.0 will be removed in 0.18
#   DeprecationWarning)

# %%
# create a mesh to plot in
x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1

# mesh resolution
h = (x_max / x_min)/100

xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))

# %%
#plt.subplot(1, 1, 1)
plt.figure(figsize=(12,8))

# plot decision regions
Z = svc.predict(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)
plt.contourf(xx, yy, Z, cmap=plt.cm.Paired, alpha=0.8)

# plot classes
plt.scatter(X[:, 0], X[:, 1], c=y, cmap=plt.cm.Paired)
plt.xlabel('Sepal length')
plt.ylabel('Sepal width')
plt.xlim(xx.min(), xx.max())
plt.title('SVC with linear kernel')

# %%
# RBF kernel

# gamma is the kernel coefficient for ‘rbf’, ‘poly’ and ‘sigmoid’. The higher the value of gamma, 
# will try to exact fit the as per training data set

# experimenting with differnet gamma values - the higher the value, the closer the fit
svc = svm.SVC(kernel='rbf', C=1,gamma=0).fit(X, y)
#svc = svm.SVC(kernel='rbf', C=1,gamma=10).fit(X, y)
#svc = svm.SVC(kernel='rbf', C=1,gamma=100).fit(X, y)
# Out:
# /Users/jmalbornoz/anaconda/lib/python2.7/site-packages/sklearn/svm/base.py:85: DeprecationWarning: gamma=0.0 has been deprecated in favor of gamma='auto' as of 0.17. Backward compatibility for gamma=0.0 will be removed in 0.18
#   DeprecationWarning)

# %%
#plt.subplot(1, 1, 1)
plt.figure(figsize=(12,8))

# plot decision regions
Z = svc.predict(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)
plt.contourf(xx, yy, Z, cmap=plt.cm.Paired, alpha=0.8)

# plot classes
plt.scatter(X[:, 0], X[:, 1], c=y, cmap=plt.cm.Paired)
plt.xlabel('Sepal length')
plt.ylabel('Sepal width')
plt.xlim(xx.min(), xx.max())
plt.title('SVC with rbf kernel')

# %%
# RBF kernel

# C: Penalty parameter of the error term. It also controls the trade off between smooth decision boundary 
# and classifying the training points correctly.

# experimenting with differnet gamma values - the higher the value, the closer the fit
#svc = svm.SVC(kernel='rbf', C=1,gamma=0).fit(X, y)
svc = svm.SVC(kernel='rbf', C=100,gamma=0).fit(X, y)
#svc = svm.SVC(kernel='rbf', C=1000,gamma=0).fit(X, y)
# Out:
# /Users/jmalbornoz/anaconda/lib/python2.7/site-packages/sklearn/svm/base.py:85: DeprecationWarning: gamma=0.0 has been deprecated in favor of gamma='auto' as of 0.17. Backward compatibility for gamma=0.0 will be removed in 0.18
#   DeprecationWarning)

# %%
#plt.subplot(1, 1, 1)
plt.figure(figsize=(12,8))

# plot decision regions
Z = svc.predict(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)
plt.contourf(xx, yy, Z, cmap=plt.cm.Paired, alpha=0.8)

# plot classes
plt.scatter(X[:, 0], X[:, 1], c=y, cmap=plt.cm.Paired)
plt.xlabel('Sepal length')
plt.ylabel('Sepal width')
plt.xlim(xx.min(), xx.max())
plt.title('SVC with rbf kernel')

# %%
# experimenting with differnet gamma values - the higher the value, the closer the fit
#svc = svm.SVC(kernel='rbf', C=1,gamma=0).fit(X, y)
#svc = svm.SVC(kernel='rbf', C=1,gamma=10).fit(X, y)
svc = svm.SVC(kernel='rbf', C=1,gamma=100).fit(X, y)
